# %%
#import dependies
import pandas as pd
import numpy as np

# %%
soccer_df = pd.read_csv('C:/Users/nannh/Desktop/Soccer Analysis/results.csv')
bundesliga_df = pd.read_csv('C:/Users/nannh/Desktop/Soccer Analysis/germany-bundesliga-1-2019-to-2020.csv')

# %%
#list(bundesliga_df.columns)

# %%
bundesliga_df
# Out:
#     Div        Date   Time            HomeTeam            AwayTeam  FTHG  \
# 0    D1  16/08/2019  19:30       Bayern Munich              Hertha     2
# 1    D1  17/08/2019  14:30            Dortmund            Augsburg     5
# 2    D1  17/08/2019  14:30            Freiburg               Mainz     3
# 3    D1  17/08/2019  14:30          Leverkusen           Paderborn     3
# 4    D1  17/08/2019  14:30       Werder Bremen  Fortuna Dusseldorf     1
# ..   ..         ...    ...                 ...                 ...   ...
# 148  D1  21/12/2019  14:30          RB Leipzig            Augsburg     3
# 149  D1  21/12/2019  14:30          Schalke 04            Freiburg     2
# 150  D1  21/12/2019  17:30              Hertha          M'gladbach     0
# 151  D1  22/12/2019  14:30  Fortuna Dusseldorf        Union Berlin     2
# 152  D1  22/12/2019  17:00           Paderborn       Ein Frankfurt     2
#
#      FTAG FTR  HTHG  SHHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  \
# ...

# %%
#create summarized scores for each half for home and away teams
bundesliga_dfh = bundesliga_df.groupby('HomeTeam').sum()
bundesliga_dfa = bundesliga_df.groupby('AwayTeam').sum()
bundesliga_dfh.copy()
bundesliga_dfa.copy()
# Out:
#                     FTHG  FTAG  HTHG  SHHG  HTAG  SHAG   HS   AS  HST  AST  \
# AwayTeam
# Augsburg              20    12     9    11     7     5  148   88   57   32
# Bayern Munich         13    18     4     9     9     9   91  130   40   51
# Dortmund              15    15     5    10     7     8  114   97   26   39
# Ein Frankfurt         15     8     7     8     1     7  107  131   48   35
# FC Koln               21    10    11    10     3     7  142  110   42   35
# Fortuna Dusseldorf    22    10     7    15     4     6  150   99   66   32
# Freiburg              14    15     7     7     8     7  174  113   61   38
# Hertha                15    11     6     9     4     7  135   84   46   34
# Hoffenheim             9    11     4     5     3     8  134   85   41   30
# Leverkusen            11    11     4     7     7     4  103  103   40   51
# M'gladbach             7    10     4     3     6     4  131   94   41   36
# ...

# %%
bundesliga_dfh
# Out:
#                     FTHG  FTAG  HTHG  SHHG  HTAG  SHAG   HS   AS  HST  AST  \
# HomeTeam
# Augsburg              16    11     8     8     4     7   94  105   39   27
# Bayern Munich         28     9     9    19     6     3  189   77   74   30
# Dortmund              26     9     7    19     5     4  145   87   64   36
# Ein Frankfurt         19    14     8    11     7     7  159  115   63   48
# FC Koln                9    11     4     5     3     8   95   86   32   29
# Fortuna Dusseldorf     8    14     4     4     9     5  107  106   33   36
# Freiburg              12     9     3     9     3     6  108  122   33   36
# Hertha                11    14     5     6     8     6   85   95   23   42
# Hoffenheim            14    19     5     9     7    12  134  105   47   39
# Leverkusen            12    10     8     4     6     4  171   75   56   31
# M'gladbach            23    11     9    14     3     8  138  126   63   36
# ...

# %%
#create a dataframe for allowed goals (needed for defense strength)
bundesliga_allowed_dfh = bundesliga_dfh[['HTAG','SHAG', 'FTAG']]
bundesliga_allowed_dfa = bundesliga_dfh[['HTHG','SHHG', 'FTHG']]
bundesliga_allowed_dfa
# Out:
#                     HTHG  SHHG  FTHG
# HomeTeam
# Augsburg               8     8    16
# Bayern Munich          9    19    28
# Dortmund               7    19    26
# Ein Frankfurt          8    11    19
# FC Koln                4     5     9
# Fortuna Dusseldorf     4     4     8
# Freiburg               3     9    12
# Hertha                 5     6    11
# Hoffenheim             5     9    14
# Leverkusen             8     4    12
# M'gladbach             9    14    23
# Mainz                  3     7    10
# Paderborn              7     5    12
# RB Leipzig            11    12    23
# Schalke 04             5     9    14
# Union Berlin           5     7    12
# Werder Bremen          4     4     8
# Wolfsburg              4     6    10

# %%
#cut down the fat for the list
bundesliga_dfh = bundesliga_dfh[['HTHG','SHHG', 'FTHG']]
bundesliga_dfa = bundesliga_dfa[['HTAG', 'SHAG', 'FTAG']]
bundesliga_dfh
# Out:
#                     HTHG  SHHG  FTHG
# HomeTeam
# Augsburg               8     8    16
# Bayern Munich          9    19    28
# Dortmund               7    19    26
# Ein Frankfurt          8    11    19
# FC Koln                4     5     9
# Fortuna Dusseldorf     4     4     8
# Freiburg               3     9    12
# Hertha                 5     6    11
# Hoffenheim             5     9    14
# Leverkusen             8     4    12
# M'gladbach             9    14    23
# Mainz                  3     7    10
# Paderborn              7     5    12
# RB Leipzig            11    12    23
# Schalke 04             5     9    14
# Union Berlin           5     7    12
# Werder Bremen          4     4     8
# Wolfsburg              4     6    10

# %%
#export to csv
bundesliga_dfh.to_csv(r'C:/Users/nannh/Desktop/Soccer Analysis/bundesliga_home_df.csv', index = False)
bundesliga_dfa.to_csv(r'C:/Users/nannh/Desktop/Soccer Analysis/bundesliga_away_df.csv', index = False)

bundesliga_allowed_dfh.to_csv(r'C:/Users/nannh/Desktop/Soccer Analysis/bundesliga_home(allowed)_df.csv', index = False)
bundesliga_allowed_dfa.to_csv(r'C:/Users/nannh/Desktop/Soccer Analysis/bundesliga_away(allowed)_df.csv', index = False)
