# %%
#import dependies
import pandas as pd
import numpy as np

# %%
soccer_df = pd.read_csv('C:/Users/nannh/Desktop/Soccer Analysis/results.csv')
bundesliga_df = pd.read_csv('C:/Users/nannh/Desktop/Soccer Analysis/germany-bundesliga-1-2019-to-2020.csv')

# %%
#turn winner column into integer

# %%
bundesliga_df
# Out:
#     Div        Date   Time            HomeTeam            AwayTeam   Average  \
# 0    D1  16/08/2019  19:30       Bayern Munich              Hertha  0.676471
# 1    D1  17/08/2019  14:30            Dortmund            Augsburg  0.647059
# 2    D1  17/08/2019  14:30            Freiburg               Mainz  0.558824
# 3    D1  17/08/2019  14:30          Leverkusen           Paderborn  0.588235
# 4    D1  17/08/2019  14:30       Werder Bremen  Fortuna Dusseldorf  0.352941
# ..   ..         ...    ...                 ...                 ...       ...
# 148  D1  21/12/2019  14:30          RB Leipzig            Augsburg  0.823529
# 149  D1  21/12/2019  14:30          Schalke 04            Freiburg  0.529412
# 150  D1  21/12/2019  17:30              Hertha          M'gladbach  0.411765
# 151  D1  22/12/2019  14:30  Fortuna Dusseldorf        Union Berlin  0.323529
# 152  D1  22/12/2019  17:00           Paderborn       Ein Frankfurt  0.294118
#
# ...

# %%
#create summarized scores for each half for home and away teams
bundesliga_dfh = bundesliga_df.groupby('HomeTeam').sum()
bundesliga_dfa = bundesliga_df.groupby('AwayTeam').sum()
bundesliga_dfh.copy()
bundesliga_dfa.copy()
# Out:
#                      Average  Winner  FTHG  FTAG  HTHG  SHHG  HTAG  SHAG   HS  \
# AwayTeam
# Augsburg            4.676471     5.5    20    12     9    11     7     5  148
# Bayern Munich       4.147059     3.0    13    18     4     9     9     9   91
# Dortmund            4.382353     4.5    15    15     5    10     7     8  114
# Ein Frankfurt       4.352941     7.0    15     8     7     8     1     7  107
# FC Koln             4.558824     6.5    21    10    11    10     3     7  142
# Fortuna Dusseldorf  4.411765     7.0    22    10     7    15     4     6  150
# Freiburg            4.294118     4.5    14    15     7     7     8     7  174
# Hertha              4.294118     5.5    15    11     6     9     4     7  135
# Hoffenheim          4.088235     3.0     9    11     4     5     3     8  134
# Leverkusen          3.647059     3.0    11    11     4     7     7     4  103
# M'gladbach          3.823529     3.5     7    10     4     3     6     4  131
# ...

# %%
bundesliga_dfh
# Out:
#                      Average  Winner  FTHG  FTAG  HTHG  SHHG  HTAG  SHAG   HS  \
# HomeTeam
# Augsburg            4.000000     5.0    16    11     8     8     4     7   94
# Bayern Munich       6.088235     6.5    28     9     9    19     6     3  189
# Dortmund            5.176471     6.5    26     9     7    19     5     4  145
# Ein Frankfurt       3.441176     5.5    19    14     8    11     7     7  159
# FC Koln             2.823529     3.5     9    11     4     5     3     8   95
# Fortuna Dusseldorf  2.588235     3.5     8    14     4     4     9     5  107
# Freiburg            4.470588     5.0    12     9     3     9     3     6  108
# Hertha              3.294118     3.5    11    14     5     6     8     6   85
# Hoffenheim          5.029412     4.5    14    19     5     9     7    12  134
# Leverkusen          5.294118     5.0    12    10     8     4     6     4  171
# M'gladbach          6.617647     7.5    23    11     9    14     3     8  138
# ...

# %%
#create a dataframe for allowed goals (needed for defense strength)
bundesliga_allowed_dfh = bundesliga_dfh[['HTAG','SHAG', 'FTAG']]
bundesliga_allowed_dfa = bundesliga_dfh[['HTHG','SHHG', 'FTHG']]
bundesliga_allowed_dfa
# Out:
#                     HTHG  SHHG  FTHG
# HomeTeam
# Augsburg               8     8    16
# Bayern Munich          9    19    28
# Dortmund               7    19    26
# Ein Frankfurt          8    11    19
# FC Koln                4     5     9
# Fortuna Dusseldorf     4     4     8
# Freiburg               3     9    12
# Hertha                 5     6    11
# Hoffenheim             5     9    14
# Leverkusen             8     4    12
# M'gladbach             9    14    23
# Mainz                  3     7    10
# Paderborn              7     5    12
# RB Leipzig            11    12    23
# Schalke 04             5     9    14
# Union Berlin           5     7    12
# Werder Bremen          4     4     8
# Wolfsburg              4     6    10

# %%
#cut down the fat for the list
bundesliga_dfh = bundesliga_dfh[['HTHG','SHHG', 'FTHG']]
bundesliga_dfa = bundesliga_dfa[['HTAG', 'SHAG', 'FTAG']]
bundesliga_dfh
# Out:
#                     HTHG  SHHG  FTHG
# HomeTeam
# Augsburg               8     8    16
# Bayern Munich          9    19    28
# Dortmund               7    19    26
# Ein Frankfurt          8    11    19
# FC Koln                4     5     9
# Fortuna Dusseldorf     4     4     8
# Freiburg               3     9    12
# Hertha                 5     6    11
# Hoffenheim             5     9    14
# Leverkusen             8     4    12
# M'gladbach             9    14    23
# Mainz                  3     7    10
# Paderborn              7     5    12
# RB Leipzig            11    12    23
# Schalke 04             5     9    14
# Union Berlin           5     7    12
# Werder Bremen          4     4     8
# Wolfsburg              4     6    10

# %%
#turn winner column into integer
bundesliga_df["Winner"] = pd.to_numeric(bundesliga_df["Winner"])

# %%
#export to csv
bundesliga_dfh.to_csv(r'C:/Users/nannh/Desktop/Soccer Analysis/bundesliga_home_df.csv', index = False)
bundesliga_dfa.to_csv(r'C:/Users/nannh/Desktop/Soccer Analysis/bundesliga_away_df.csv', index = False)

bundesliga_allowed_dfh.to_csv(r'C:/Users/nannh/Desktop/Soccer Analysis/bundesliga_home(allowed)_df.csv', index = False)
bundesliga_allowed_dfa.to_csv(r'C:/Users/nannh/Desktop/Soccer Analysis/bundesliga_away(allowed)_df.csv', index = False)

# %%
bundesliga_df
# Out:
#     Div        Date   Time            HomeTeam            AwayTeam   Average  \
# 0    D1  16/08/2019  19:30       Bayern Munich              Hertha  0.676471
# 1    D1  17/08/2019  14:30            Dortmund            Augsburg  0.647059
# 2    D1  17/08/2019  14:30            Freiburg               Mainz  0.558824
# 3    D1  17/08/2019  14:30          Leverkusen           Paderborn  0.588235
# 4    D1  17/08/2019  14:30       Werder Bremen  Fortuna Dusseldorf  0.352941
# ..   ..         ...    ...                 ...                 ...       ...
# 148  D1  21/12/2019  14:30          RB Leipzig            Augsburg  0.823529
# 149  D1  21/12/2019  14:30          Schalke 04            Freiburg  0.529412
# 150  D1  21/12/2019  17:30              Hertha          M'gladbach  0.411765
# 151  D1  22/12/2019  14:30  Fortuna Dusseldorf        Union Berlin  0.323529
# 152  D1  22/12/2019  17:00           Paderborn       Ein Frankfurt  0.294118
#
# ...

# %%
bundesliga_data_df=bundesliga_df[["HomeTeam","AwayTeam","FTHG","FTAG"]]

# %%
bundesliga_data_df
# Out:
#                HomeTeam            AwayTeam  FTHG  FTAG
# 0         Bayern Munich              Hertha     2     2
# 1              Dortmund            Augsburg     5     1
# 2              Freiburg               Mainz     3     0
# 3            Leverkusen           Paderborn     3     2
# 4         Werder Bremen  Fortuna Dusseldorf     1     3
# ..                  ...                 ...   ...   ...
# 148          RB Leipzig            Augsburg     3     1
# 149          Schalke 04            Freiburg     2     2
# 150              Hertha          M'gladbach     0     0
# 151  Fortuna Dusseldorf        Union Berlin     2     1
# 152           Paderborn       Ein Frankfurt     2     1
#
# [153 rows x 4 columns]

# %%
#create averages for each type of scoring
bundesliga_df['par1'] = bundesliga_df['FTHG'].groupby(bundesliga_df['HomeTeam']).transform('mean') 
bundesliga_df['par2'] = bundesliga_df['FTHG'].groupby(bundesliga_df['AwayTeam']).transform('mean') 
bundesliga_df['par3'] = bundesliga_df['FTAG'].groupby(bundesliga_df['HomeTeam']).transform('mean') 
bundesliga_df['par4'] = bundesliga_df['FTAG'].groupby(bundesliga_df['AwayTeam']).transform('mean') 

bundesliga_df.sort_values(['HomeTeam','AwayTeam']).head(14)
# Out:
#     Div        Date   Time       HomeTeam            AwayTeam   Average  \
# 64   D1  19/10/2019  14:30       Augsburg       Bayern Munich  0.500000
# 28   D1  14/09/2019  14:30       Augsburg       Ein Frankfurt  0.500000
# 136  D1  17/12/2019  19:30       Augsburg  Fortuna Dusseldorf  0.500000
# 106  D1  24/11/2019  14:30       Augsburg              Hertha  0.500000
# 46   D1  28/09/2019  14:30       Augsburg          Leverkusen  0.500000
# 118  D1   7/12/2019  14:30       Augsburg               Mainz  0.500000
# 89   D1   3/11/2019  17:00       Augsburg          Schalke 04  0.500000
# 10   D1  24/08/2019  14:30       Augsburg        Union Berlin  0.500000
# 95   D1   9/11/2019  17:30  Bayern Munich            Dortmund  0.676471
# 37   D1  21/09/2019  14:30  Bayern Munich             FC Koln  0.676471
# 0    D1  16/08/2019  19:30  Bayern Munich              Hertha  0.676471
# 55   D1   5/10/2019  14:30  Bayern Munich          Hoffenheim  0.676471
# ...

# %%
# Change text into variables
bundesliga_df = pd.get_dummies(bundesliga_df)
bundesliga_df.head(5)
# Out:
#     Average  Winner  FTHG  FTAG  HTHG  SHHG  HTAG  SHAG  HS  AS  ...  \
# 0  0.676471     0.5     2     2     1     1     2     0  17   6  ...
# 1  0.647059     1.0     5     1     1     4     1     0  23   5  ...
# 2  0.558824     1.0     3     0     0     3     0     0  19  19  ...
# 3  0.588235     1.0     3     2     2     1     2     0  13  11  ...
# 4  0.352941     0.0     1     3     0     1     1     2  23  12  ...
#
#    AwayTeam_Schalke 04  AwayTeam_Union Berlin  AwayTeam_Werder Bremen  \
# 0                    0                      0                       0
# 1                    0                      0                       0
# 2                    0                      0                       0
# 3                    0                      0                       0
# 4                    0                      0                       0
#
#    AwayTeam_Wolfsburg  FTR_A  FTR_D  FTR_H  HTR_A  HTR_D  HTR_H
# 0                   0      0      1      0      1      0      0
# ...

# %%
print('How big is our dataframe? ', bundesliga_df.shape)
# Out:
# How big is our dataframe?  (153, 206)

# %%
bundesliga_df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-6470da5cae7e> in <module>
# ----> 1 bundesliga_df.columns()
#
# TypeError: 'Index' object is not callable

# %%
#turn winner column into integer
bundesliga_df.dtypes
# Out:
# Average    float64
# Winner     float64
# FTHG         int64
# FTAG         int64
# HTHG         int64
#             ...
# FTR_D        uint8
# FTR_H        uint8
# HTR_A        uint8
# HTR_D        uint8
# HTR_H        uint8
# Length: 206, dtype: object

# %%
# Labels are the values we want to predict
labels = np.array(bundesliga_df['Winner'])

# Remove the labels from the features
# axis 1 refers to the columns
bundesliga_df= bundesliga_df.drop('Winner', axis = 1)

# Saving feature names for later use
feature_list = list(bundesliga_df.columns)

# Convert to numpy array
bundesliga_df = np.array(bundesliga_df)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(bundesliga_df, labels, test_size = 11,
                                                                           random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (142, 205)
# Training Labels Shape: (142,)
# Testing Features Shape: (11, 205)
# Testing Labels Shape: (11,)

# %%
# The baseline predictions are the historical averages
baseline_preds = test_features[:, feature_list.index('Average')]

# Baseline errors, and display average baseline error
baseline_errors = abs(baseline_preds - test_labels)
print('Average baseline error: ', round(np.mean(baseline_errors), 2), 'degrees.')
# Out:
# Average baseline error:  0.38 degrees.

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

# Instantiate model 
rf = RandomForestRegressor(n_estimators= 1000, random_state=42)

# Train the model on training data
rf.fit(train_features, train_labels);

# %%
rf_new = RandomForestRegressor(n_estimators = 100, criterion = 'mse', max_depth = None, 
                               min_samples_split = 5, min_samples_leaf = 1)

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)

# Calculate the absolute errors
errors = abs(predictions - test_labels)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 0.0 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: nan %.
# C:\Users\nannh\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: nan %.
# C:\Users\nannh\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %%
#create blank win column and create control and test variables
win=[]
for l in range(0,len(bundesliga_df)):
    if bundesliga_df.FTHG[l]>bundesliga_df.FTAG[l]:
        k1=1
        win.append(k1)
    else:
        k1=0
        win.append(k1)
df2=pd.DataFrame({"mx1":bundesliga_df.par1,"mx2":bundesliga_df.par2,"mx3":bundesliga_df.par3,"mx4":bundesliga_df.par4,"a":win})
from sklearn.model_selection import train_test_split
df2train, df2test= train_test_split(
 df2, test_size=0.35, random_state=42)

df2=np.array(df2)
df2test=np.array(df2test)
Y=df2[:,0]
X=df2[:,1:5]
Y1=df2test[:,0]
X1=df2test[:,1:5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-3ae687cc9a88> in <module>
#       2 win=[]
#       3 for l in range(0,len(bundesliga_df)):
# ----> 4     if bundesliga_df.FTHG[l]>bundesliga_df.FTAG[l]:
#       5         k1=1
#       6         win.append(k1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'FTHG'

# %%
#run and gage accuracy of XBCLassifier ML Model
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X,Y)
from sklearn.metrics import accuracy_score
y_pred = model.predict(X1)
predictions = [round(value) for value in y_pred]

# %%
## KNeighbors Model
from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
seed = 42
kfold = model_selection.KFold(n_splits=2, random_state=None)
model1 = KNeighborsClassifier()
model1.fit(X,Y)
y_pred = model1.predict(X1)
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(Y1, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %%
## Logistic Regression Model

from sklearn.linear_model import LogisticRegression
seed = 42
kfold = model_selection.KFold(n_splits=2, random_state=seed)
model4 = LogisticRegression()
model4.fit(X,Y)
y_pred = model4.predict(X1)
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(Y1, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
